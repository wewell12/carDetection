# %% [markdown]
# # Optimisation de la détection de voitures sur une image à l'aide d'un model de classification

# %% [markdown]
# liens des datasets :
# - dataset de classification : https://www.kaggle.com/datasets/brsdincer/vehicle-detection-image-set
# - dataset de détection : https://www.kaggle.com/datasets/ashfakyeafi/road-vehicle-images-dataset

# %% [markdown]
# **Toutes les fonctions que que nous avons codé sont dans les notebooks ou dans l'un des fichiers du dossier libs.**

# %% [markdown]
# ## Création du model de classification

# %% [markdown]
# ![small_images.png](attachment:2a435db7-d441-4741-a630-9178ba10d62a.png)

# %% [markdown]
# le notebook associé : [(ici)](first_net.ipynb)

# %% [markdown]
# ## Récupération des voitures sur le deuxième dataset

# %% [markdown]
# ![true.png](attachment:0ef16e28-7675-46a7-9648-62ae3aa595b4.png)

# %% [markdown]
# le notebook associé : [(ici)](true_labels.ipynb)

# %% [markdown]
# ## Utilisation du réseau de neuronnes sur le deuxième dataset

# %% [markdown]
# ![true_map_img.png](attachment:fca73660-195f-404a-8b9f-15da2e115e9c.png)

# %% [markdown]
# ![heat_map_img.png](attachment:0b25c380-e01f-4e3d-87d4-2886798e30f4.png)

# %% [markdown]
# le notebook associé : [(ici)](big_images.ipynb)

# %% [markdown]
# ## sélections et optimisation des paramètres du model

# %% [markdown]
# ![results.png](attachment:35bcd62d-c768-4d7d-bd99-977eb23f6f4f.png)

# %% [markdown]
# le notebook associé : [(ici)](parameters_selection.ipynb)
